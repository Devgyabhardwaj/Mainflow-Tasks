# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('C:\\Users\\Devgya\\Desktop\\DATA ANAYLTYICS\\heart.csv')

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
# look at name of the comlumns
df.columns.values
# Out:
# array(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg',
#        'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype=object)

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
#concise summary of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
#plotting histogram of all numeric values
df.hist(bins = 50 , grid = False , figsize= (20,15));

# %%
#generating a descriptive set
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
questions = ["1. How many people have heart disease and how many people don't have heart disease",
             "2. People of which sex has most heart disease?",
             "3. People of which sex has which type of chest pain most ?",
             "4. People with which chest pain are most pron to have heart disease?"
             "5. People of which age has the most heart disease"
             "6. Which sex has higest Exang problem"
             "7. People of which sex has which type of ca (number of major vessels)"]

questions
# Out:
# ["1. How many people have heart disease and how many people don't have heart disease",
#  '2. People of which sex has most heart disease?',
#  '3. People of which sex has which type of chest pain most ?',
#  '4. People with which chest pain are most pron to have heart disease?5. People of which age has the most heart disease6. Which sex has higest Exang problem7. People of which sex has which type of ca (number of major vessels)']

# %%
# Variables used in dataset 

1 #age (Age in years)
2 #sex : (1 = male, 0 = female)
3 #cp (Chest Pain Type): [ 0: asymptomatic, 1: atypical angina, 2: non-anginal pain, 3: typical angina]
4 #trestbps (Resting Blood Pressure in mm/hg )
5 #chol (Serum Cholesterol in mg/dl)
6 #fps (Fasting Blood Sugar > 120 mg/dl): [0 = no, 1 = yes]
7 #restecg (Resting ECG): [0: showing probable or definite left ventricular hypertrophy by Estes’ criteria, 1: normal, 2: having ST-T wave abnormality]
8 #thalach (maximum heart rate achieved)
9 #exang (Exercise Induced Angina): [1 = yes, 0 = no]
10 #oldpeak (ST depression induced by exercise relative to rest)
11 #slope (the slope of the peak exercise ST segment): [0: downsloping; 1: flat; 2: upsloping]
12 #ca [number of major vessels (0–3)
13 #thal : [1 = normal, 2 = fixed defect, 3 = reversible defect]
14 #target: [0 = disease, 1 = no disease]

# %%
# 1. How many people have heart disease and how many people don't have heart disease
#1-positive
#2-negative

df.target.value_counts()
# Out:
# target
# 1    526
# 0    499
# Name: count, dtype: int64

# %%
#plotting the bar chart
df.target.value_counts().plot(kind = 'bar' , color=["orchid","salmon"])
plt.title("Heart Disease Values")
plt.xlabel("1 = Heart Diseases , 0 = No Heart Diseases")
plt.ylabel("Amount");

# %%
#Plotting a pie chart 
df.target.value_counts().plot(kind = 'pie' , figsize = (8,6))
plt.legend(["Disease","No Disease"]);

# %%
#0 represents 'Female'
#1 represents 'male'

#sex coloumn part

#0 represent 'No disease'
#1 represent 'Disease'

#Target column part 
#Checking how  many male and female are in the dataset
df.sex.value_counts()
# Out:
# sex
# 1    713
# 0    312
# Name: count, dtype: int64

# %%
#plotting a pie chart
df.sex.value_counts().plot(kind = 'pie' , figsize = (8,6));
plt.title("Male female Ratio")
plt.legend(['Male','Female'])

# %%
# 2. People of which sex has most heart disease?
pd.crosstab(df.target,df.sex)
# Out:
# sex       0    1
# target
# 0        86  413
# 1       226  300

# %%
# plotting barchart for the same
sns.countplot(x='target' ,data=df , hue='sex')
plt.title("Heart Disease Frequency for Sex")
plt.xlabel("0 = No heart disease , 1 = heart disease");

# %%
#3. People of which sex has which type of chest pain most ?
df.cp.value_counts()
# Out:
# cp
# 0    497
# 2    284
# 1    167
# 3     77
# Name: count, dtype: int64

# %%
#plotting a bar chart
df.cp.value_counts().plot(kind='bar',color = ['salmon','lightskyblue','springgreen','khaki'])
plt.title('Chest pain type vs Count');

# %%
pd.crosstab(df.sex , df.cp)
# Out:
# cp     0    1    2   3
# sex
# 0    133   57  109  13
# 1    364  110  175  64

# %%
pd.crosstab(df.sex , df.cp).plot(kind='bar',color = ['coral','lightskyblue','plum','khaki'])
plt.title('Type of chest pain for sex')
plt.xlabel('0 = Female , 1 = Male');

# %%
#Most of the male has type0 chest pain and least of male has type4 chest pain
#In case of female type0 and type2 percentage are almost same.

# %%
#4. People with which chest pain are most pron to have heart disease?
pd.crosstab(df.cp , df.target)
# Out:
# target    0    1
# cp
# 0       375  122
# 1        33  134
# 2        65  219
# 3        26   51

# %%
 sns.countplot(x = 'cp', data = df, hue = 'target');

# %%
#Most of the people who has 'type0' chestpain has less chance of heart disease
#And we see the opposite for other types

#Now let's take a look at out age column.

#create a distribution plot with normal distribution curve
sns.displot(x = 'age', data = df , bins = 30 ,kde = True);

# %%
# 58-59 year old people are most in the dataset.

#let's plo another distribution plot for maximum heart rate
sns.displot(x = 'thalach' , data = df , bins = 30 , kde = True , color = 'chocolate');

# %%
#5. People of which age has the most heart disease
pd.crosstab(df.age,df.target)
# Out:
# target   0   1
# age
# 29       0   4
# 34       0   6
# 35       7   8
# 37       0   6
# 38       4   8
# 39       4  10
# 40       8   3
# 41       3  29
# 42       4  22
# 43      11  15
# 44      10  26
# 45       6  19
# 46      11  12
# 47       8  10
# 48      11  12
# 49       8   9
# 50       9  12
# 51      10  29
# 52      15  28
# 53       8  18
# 54      21  32
# 55      20  10
# 56      22  17
# 57      36  21
# 58      44  24
# 59      31  15
# 60      27  10
# 61      28   3
# 62      24  13
# 63      23   9
# 64      15  19
# 65      15  12
# 66      11  14
# 67      22   9
# 68       6   6
# 69       3   6
# 70      11   3
# 71       0  11
# 74       0   3
# 76       0   3
# 77       3   0

# %%
pd.crosstab(df.age,df.target).plot(kind='bar',color = ['coral','lightskyblue'])
plt.title("Heart disease according to the age")
plt.xlabel('0 = heart disease','1 = No heart disease');
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[104], line 3
#       1 pd.crosstab(df.age,df.target).plot(kind='bar',color = ['coral','lightskyblue'])
#       2 plt.title("Heart disease according to the age")
# ----> 3 plt.xlabel('0 = heart disease','1 = No heart disease')
#
# File D:\ANACONDA\Lib\site-packages\matplotlib\pyplot.py:4150, in xlabel(xlabel, fontdict, labelpad, loc, **kwargs)
#    4141 @_copy_docstring_and_deprecators(Axes.set_xlabel)
#    4142 def xlabel(
#    4143     xlabel: str,
#    (...)
#    4148     **kwargs,
#    4149 ) -> Text:
# -> 4150     return gca().set_xlabel(
#    4151         xlabel, fontdict=fontdict, labelpad=labelpad, loc=loc, **kwargs
#    4152     )
#
# File D:\ANACONDA\Lib\site-packages\matplotlib\axes\_base.py:3481, in _AxesBase.set_xlabel(self, xlabel, fontdict, labelpad, loc, **kwargs)
#    3474     x = {
# ...

# %%
# people of the age 57-60 has the mximum chances of heart disease

# %%
#6. Which sex has higest Exang problem
pd.crosstab(df.sex,df.exang)
# Out:
# exang    0    1
# sex
# 0      238   74
# 1      442  271

# %%
pd.crosstab(df.sex , df.exang).plot(kind='bar',color = ['coral','lightskyblue'])
plt.title('Exang problem in differnt sex')
plt.xlabel('0 = Female , 1 = Male');

# %%
#Female has less exang problem as compared to male.

# %%
#7.Types of ca (number of major vessels) for sex
pd.crosstab(df.sex ,df.ca)
# Out:
# ca     0    1   2   3   4
# sex
# 0    204   49  45  14   0
# 1    374  177  89  55  18

# %%
pd.crosstab(df.sex , df.ca).plot(kind='bar',color = ['coral','lightskyblue','plum','khaki'])
plt.title('Type of ca vessels for sex')
plt.xlabel('0 = Female , 1 = Male');

# %%
#Both male and females have the 0 type of vessels highest
